# %%
import pandas as pd
import numpy as np
df = pd.read_excel('D:/Projects/RedCarpetUp/dataset.xls',header=1)
df.head(3)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
#
#                                 A) Brief Description  B) Year Established  \
# 0  The Division of Ocean Sciences seeks to establ...               2002.0
# 1  The BPC Program was not primarily aimed at edu...               2006.0
# 2  Through the CISE Pathways to Revitalized Under...               2007.0
#
# ...

# %%
df.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          231.000000          244.000000
# mean           1998.464730           24.215027           27.495004
# std              11.653317          185.603047          216.895416
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.688500            0.760072
# 50%            2002.000000            2.047000            2.211000
# 75%            2007.000000            8.400399            9.054625
# max            2010.000000         2796.835667         3354.390546
#
#        C3) Funding FY2010  P) External Funding Allocation  \
# count          253.000000                             0.0
# mean            27.077364                             NaN
# std            217.438894                             NaN
# min              0.000000                             NaN
# 25%              0.857000                             NaN
# ...

# %%
for i in df.columns:
    if i[:7] == "Unnamed":
        df.rename(columns={i:j+" "+str(k)},inplace=True)
        k=k+1
    else:
        j=i
        k=1

# %%
df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %% [markdown]
# # stage 1:-

# %% [markdown]
# # handling the missing values

# %%
print("no. of nan values in the FY2008 is = "+str(df['C1) Funding FY2008'].isnull().sum()))
print("no. of nan values in the FY2009 is = "+str(df['C2) Funding FY2009'].isnull().sum()))
# Out:
# no. of nan values in the FY2008 is = 22
# no. of nan values in the FY2009 is = 9

# %%
df['C1) Funding FY2008'].fillna(0,inplace=True)
print("no. of nan values in the FY2008 after handling is  = "+str(df['C1) Funding FY2008'].isnull().sum()))
# Out:
# no. of nan values in the FY2008 after handling is  = 0

# %%
df['C2) Funding FY2009'].fillna(0,inplace=True)
print("no. of nan values in the FY2009 after handling is  = "+str(df['C2) Funding FY2009'].isnull().sum()))
# Out:
# no. of nan values in the FY2009 after handling is  = 0

# %% [markdown]
# # Creating a column 'percent_growth'

# %% [markdown]
# # Task -1

# %%
df['percent_growth']=""

# %%
for i in range(len(df1)):
    if df['C1) Funding FY2008'][i]==0.0:
        if df['C2) Funding FY2009'][i]==0.0:
            df['percent_growth'][i]=0
        elif df['C2) Funding FY2009'][i]<0.0:
            df['percent_growth'][i]=-100.0
        else:
            df['percent_growth'][i]=100.0
    else:
        df['percent_growth'][i]=100*((df['C2) Funding FY2009'][i]-df['C1) Funding FY2008'][i])/df['C1) Funding FY2008'][i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# # Creating the 'Target' label

# %%
df['Target']=""

# %%
df['Target'] = (df['percent_growth'] >= 0).astype(int)

# %%
df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %% [markdown]
# # Stage 2:-

# %%
df1=df
df_after_1=df

# %% [markdown]
# # Handliing the missing values

# %%
df.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          253.000000          253.000000
# mean           1998.464730           22.109373           26.516921
# std              11.653317          177.448085          213.048189
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.476000            0.713000
# 50%            2002.000000            1.670000            2.000000
# 75%            2007.000000            6.800000            8.400000
# max            2010.000000         2796.835667         3354.390546
#
#        C3) Funding FY2010  P) External Funding Allocation  \
# count          253.000000                             0.0
# mean            27.077364                             NaN
# std            217.438894                             NaN
# min              0.000000                             NaN
# 25%              0.857000                             NaN
# ...

# %% [markdown]
# # Note-

# %% [markdown]
# Since the count, mean and std are showing that they have all values are missing so we can remove them.

# %%
df=df.drop(['P) External Funding Allocation','R1) Joint Funding of Investment (with Agencies)'],axis=1)

# %%
df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %%
df.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          253.000000          253.000000
# mean           1998.464730           22.109373           26.516921
# std              11.653317          177.448085          213.048189
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.476000            0.713000
# 50%            2002.000000            1.670000            2.000000
# 75%            2007.000000            6.800000            8.400000
# max            2010.000000         2796.835667         3354.390546
#
#        C3) Funding FY2010  R1) Joint Funding of Investment (with Agencies) 2  \
# count          253.000000                                          12.000000
# mean            27.077364                                           1.650048
# std            217.438894                                           1.910847
# ...

# %% [markdown]
# # Note-

# %% [markdown]
# Since count of some features are very low so we can remove them.

# %%
df=df.drop(['R1) Joint Funding of Investment (with Agencies) 2','R1) Joint Funding of Investment (with Agencies) 5',
             'R1) Joint Funding of Investment (with Agencies) 8','R1) Joint Funding of Investment (with Agencies) 11',
             'R2) Joint Funding of Investment (with Other) 4','R2) Joint Funding of Investment (with Other) 7',
             'R2) Joint Funding of Investment (with Other) 10'],axis=1)

# %%
df.head(5)
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %%
df.describe()
# Out:
#        B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# count           241.000000          253.000000          253.000000
# mean           1998.464730           22.109373           26.516921
# std              11.653317          177.448085          213.048189
# min            1914.000000            0.000000            0.000000
# 25%            1993.000000            0.476000            0.713000
# 50%            2002.000000            1.670000            2.000000
# 75%            2007.000000            6.800000            8.400000
# max            2010.000000         2796.835667         3354.390546
#
#        C3) Funding FY2010      Target
# count          253.000000  253.000000
# mean            27.077364    0.794466
# std            217.438894    0.404892
# min              0.000000    0.000000
# 25%              0.857000    1.000000
# 50%              2.461000    1.000000
# 75%              9.327000    1.000000
# max           3425.286526    1.000000

# %%
df2=df

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Task 1-

# %% [raw]
# collecting the all non funding vriable

# %%
df2=df2.drop(['C1) Funding FY2008','C2) Funding FY2009','C3) Funding FY2010'],axis=1)

# %%
df2.columns
# Out:
# Index(['Index Number', 'Investment Name', 'Agency', 'Subagency',
#        'A) Brief Description', 'B) Year Established',
#        'D) Mission-specific or General STEM?',
#        'E) Agency or Mission-Related Workforce Needs?',
#        'F1) Primary Investment Objective',
#        'F2) Secondary Investment Objectives',
#        ...
#        'Y3) Process or Implementation Evaluation Type',
#        'Y3) Process or Implementation Evaluation Type 1',
#        'Y3) Process or Implementation Evaluation Type 2',
#        'Y4) Portfolio Evaluation/Review Type',
#        'Y4) Portfolio Evaluation/Review Type 1',
#        'Y4) Portfolio Evaluation/Review Type 2', 'Y5) Expert Review Type',
#        'Y5) Expert Review Type 1', 'percent_growth', 'Target'],
#       dtype='object', length=246)

# %%
df2.shape
# Out:
# (253, 246)

# %% [markdown]
# # Featuring Engineering

# %% [markdown]
# # 1. reducing the no. of features

# %% [raw]
# removing the features who have more number of null values

# %%
for each in df2.columns:
    if ( df2[each].isnull().sum() > int(252*.6)):
        df2 = df2.drop(each,axis=1)

# %%
df2.shape
# Out:
# (253, 37)

# %%
columns=df2.columns

# %%
columns
# Out:
# Index(['Index Number', 'Investment Name', 'Agency', 'Subagency',
#        'A) Brief Description', 'B) Year Established',
#        'D) Mission-specific or General STEM?',
#        'E) Agency or Mission-Related Workforce Needs?',
#        'F1) Primary Investment Objective',
#        'F2) Secondary Investment Objectives',
#        'F2) Secondary Investment Objectives 1',
#        'H) Educational Services or Products Produced',
#        'H) Educational Services or Products Produced 1',
#        'H) Educational Services or Products Produced 2',
#        'H) Educational Services or Products Produced 4',
#        'H) Educational Services or Products Produced 7',
#        'H) Educational Services or Products Produced 9',
#        'H) Educational Services or Products Produced 10',
#        'I1) STEM Learners Targeted? Specify.',
#        'I1) STEM Learners Targeted? Specify. 5',
#        'I1) STEM Learners Targeted? Specify. 6',
#        'J) Focus on Underrepresented Groups in STEM',
# ...

# %%
for each in df2.columns:
    if(len(list(df2[each].value_counts())) ==252) or (len(list(df2[each].value_counts())) ==251) or (len(list(df2[each].value_counts())) ==250)or (len(list(df2[each].value_counts())) ==1):
        df2 = df2.drop(each,axis=1)

# %%
df2.shape
# Out:
# (253, 22)

# %%
columns=df2.columns
columns
# Out:
# Index(['Agency', 'Subagency', 'B) Year Established',
#        'D) Mission-specific or General STEM?',
#        'E) Agency or Mission-Related Workforce Needs?',
#        'F1) Primary Investment Objective',
#        'I1) STEM Learners Targeted? Specify.',
#        'I1) STEM Learners Targeted? Specify. 5',
#        'I1) STEM Learners Targeted? Specify. 6',
#        'J) Focus on Underrepresented Groups in STEM',
#        'K) Eligibility Restrictions', 'L) Minority Serving Institutions',
#        'M) Geographic Region', 'M) Geographic Region 1',
#        'N) STEM Discipline Focus 12',
#        'Q) Legislation Required to Shift Focus?', 'S) Investment Partnerships',
#        'U) Measured Outputs', 'V) Outcomes Measured',
#        'X) Evaluated Since 2005?', 'percent_growth', 'Target'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Agency

# %%
df2['Agency'].value_counts().plot(kind = 'bar')
plt.xlabel('Agency')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
df2['Agency'].value_counts().plot(kind = 'pie')

# %% [markdown]
# # Target

# %%
df2['Target'].value_counts().plot(kind = 'bar')
plt.xlabel('Target')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
df2['Target'].value_counts().plot(kind = 'pie')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 22 columns):
# Agency                                           252 non-null object
# Subagency                                        237 non-null object
# B) Year Established                              241 non-null float64
# D) Mission-specific or General STEM?             252 non-null object
# E) Agency or Mission-Related Workforce Needs?    110 non-null object
# F1) Primary Investment Objective                 252 non-null object
# I1) STEM Learners Targeted? Specify.             209 non-null object
# I1) STEM Learners Targeted? Specify. 5           131 non-null object
# I1) STEM Learners Targeted? Specify. 6           104 non-null object
# J) Focus on Underrepresented Groups in STEM      252 non-null object
# K) Eligibility Restrictions                      252 non-null object
# L) Minority Serving Institutions                 181 non-null object
# ...

# %% [markdown]
# Subagency

# %%
len(df['Subagency'].unique())
# Out:
# 65

# %% [markdown]
# Year Established

# %%
len(df['B) Year Established'].unique())
# Out:
# 40

# %% [markdown]
# General SEM

# %%
len(df['D) Mission-specific or General STEM?'].unique())
# Out:
# 3

# %%
df2['D) Mission-specific or General STEM?'].value_counts().plot(kind = 'bar')
plt.xlabel('Target')
plt.ylabel('Mission-specific or General STEM')
# Out:
# Text(0,0.5,'Mission-specific or General STEM')

# %% [markdown]
# Agency or Mission-Related Workforce Needs?

# %%
len(df['E) Agency or Mission-Related Workforce Needs?'].unique())
# Out:
# 3

# %%
df2['E) Agency or Mission-Related Workforce Needs?'].value_counts().plot(kind = 'bar')
plt.xlabel('Target')
plt.ylabel('Agency or Mission-Related Workforce Needs')
# Out:
# Text(0,0.5,'Agency or Mission-Related Workforce Needs')

# %% [markdown]
# Primary Investment Objective

# %%
len(df['F1) Primary Investment Objective'].unique())
# Out:
# 8

# %%
df2['F1) Primary Investment Objective'].value_counts().plot(kind = 'bar')
plt.xlabel('Primary Investment Objective')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# STEM Learners Targeted? Specify.

# %%
len(df['I1) STEM Learners Targeted? Specify.'].unique())
# Out:
# 3

# %%
df2['I1) STEM Learners Targeted? Specify.'].value_counts().plot(kind = 'bar')
plt.xlabel('STEM Learners Targeted? Specify')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# STEM Learners Targeted? Specify. 5

# %%
len(df['I1) STEM Learners Targeted? Specify. 5'].unique())
# Out:
# 3

# %%
df2['I1) STEM Learners Targeted? Specify. 5'].value_counts().plot(kind = 'bar')
plt.xlabel('STEM Learners Targeted? Specify')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# STEM Learners Targeted? Specify. 6

# %%
len(df['I1) STEM Learners Targeted? Specify. 6'].unique())
# Out:
# 3

# %%
df2['I1) STEM Learners Targeted? Specify. 6'].value_counts().plot(kind = 'bar')
plt.xlabel('STEM Learners Targeted? Specify')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# Focus on Underrepresented Groups in STEM

# %%
len(df['J) Focus on Underrepresented Groups in STEM'].unique())
# Out:
# 3

# %%
df2['J) Focus on Underrepresented Groups in STEM'].value_counts().plot(kind = 'bar')
plt.xlabel('Focus on Underrepresented Groups in STEM')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# percent_growth

# %%
len(df['percent_growth'].unique())
# Out:
# 183

# %% [markdown]
# X) Evaluated Since 2005?

# %%
len(df['X) Evaluated Since 2005?'].unique())
# Out:
# 3

# %%
df2['X) Evaluated Since 2005?'].value_counts().plot(kind = 'bar')
plt.xlabel('Evaluated Since 2005')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# V) Outcomes Measured

# %%
len(df['V) Outcomes Measured'].unique())
# Out:
# 3

# %%
df2['V) Outcomes Measured'].value_counts().plot(kind = 'bar')
plt.xlabel('Outcomes Measured')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 22 columns):
# Agency                                           252 non-null object
# Subagency                                        237 non-null object
# B) Year Established                              241 non-null float64
# D) Mission-specific or General STEM?             252 non-null object
# E) Agency or Mission-Related Workforce Needs?    110 non-null object
# F1) Primary Investment Objective                 252 non-null object
# I1) STEM Learners Targeted? Specify.             209 non-null object
# I1) STEM Learners Targeted? Specify. 5           131 non-null object
# I1) STEM Learners Targeted? Specify. 6           104 non-null object
# J) Focus on Underrepresented Groups in STEM      252 non-null object
# K) Eligibility Restrictions                      252 non-null object
# L) Minority Serving Institutions                 181 non-null object
# ...

# %% [markdown]
# Eligibility Restrictions

# %%
len(df['K) Eligibility Restrictions'].unique())
# Out:
# 3

# %%
df2['K) Eligibility Restrictions'].value_counts().plot(kind = 'bar')
plt.xlabel('Eligibility Restrictions')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %% [markdown]
# # Task-2

# %% [markdown]
# # Mutual_info_score of target variable created in stage 1 & ALL non funding variables

# %%
from sklearn.metrics import mutual_info_score
from sklearn.preprocessing import LabelEncoder

# %%
df3=df

# %%
df3.head()
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %%
df3.head()
# Out:
#   Index Number                                    Investment Name  \
# 0     PRG_0001  Centers for Ocean Sciences Education Excellence ~
# 1     PRG_0002        Broadening Participation in Computing (BPC)
# 2     PRG_0003  CISE Pathways to Revitalized Undergraduate Com...
# 3     PRG_0004  Opportunities for Enhancing Diversity in the G...
# 4     PRG_0005                               Geoscience Education
#
#                         Agency  \
# 0  National Science Foundation
# 1  National Science Foundation
# 2  National Science Foundation
# 3  National Science Foundation
# 4  National Science Foundation
#
#                                            Subagency  \
# 0                  Directorate for Geosciences (GEO)
# 1  Directorate for Computer & Information Science...
# 2  Directorate for Computer & Information Science...
# 3                  Directorate for Geosciences (GEO)
# 4                  Directorate for Geosciences (GEO)
#
# ...

# %%
df.columns.values
# Out:
# array(['Index Number', 'Investment Name', 'Agency', 'Subagency',
#        'A) Brief Description', 'B) Year Established',
#        'C1) Funding FY2008', 'C2) Funding FY2009', 'C3) Funding FY2010',
#        'D) Mission-specific or General STEM?',
#        'E) Agency or Mission-Related Workforce Needs?',
#        'F1) Primary Investment Objective',
#        'F2) Secondary Investment Objectives',
#        'F2) Secondary Investment Objectives 1',
#        'F2) Secondary Investment Objectives 2',
#        'F2) Secondary Investment Objectives 3',
#        'F2) Secondary Investment Objectives 4',
#        'F2) Secondary Investment Objectives 5',
#        'F2) Secondary Investment Objectives 6',
#        'F2) Secondary Investment Objectives 7',
#        'F2) Secondary Investment Objectives 8',
#        'F2) Secondary Investment Objectives 9',
#        'G1) Primary Research Approaches',
#        'G1) Primary Research Approaches 1',
#        'G1) Primary Research Approaches 2',
# ...

# %%
le=LabelEncoder()
for each in df.columns.values:
    if df[each].dtypes=='object':
        le.fit(df[each].astype(str))
        df[each]=le.transform(df[each].astype(str))

# %% [markdown]
# # Mutual info score

# %%
df.corr()
# Out:
#                                                  Index Number  \
# Index Number                                         1.000000
# Investment Name                                      0.095262
# Agency                                              -0.529044
# Subagency                                            0.167479
# A) Brief Description                                 0.127129
# B) Year Established                                 -0.113446
# C1) Funding FY2008                                   0.104975
# C2) Funding FY2009                                   0.102017
# C3) Funding FY2010                                   0.108344
# D) Mission-specific or General STEM?                -0.353611
# E) Agency or Mission-Related Workforce Needs?       -0.330614
# F1) Primary Investment Objective                     0.197403
# F2) Secondary Investment Objectives                  0.073857
# F2) Secondary Investment Objectives 1                0.042771
# ...

# %% [markdown]
# # Stage 3:-

# %%
df.head()
df_after_2=df

# %%
df.head()
# Out:
#    Index Number  Investment Name  Agency  Subagency  A) Brief Description  \
# 0             0               31      10         12                    92
# 1             1               23      10          9                    76
# 2             2               26      10          9                   240
# 3             3              174      10         12                   163
# 4             4               72      10         12                   107
#
#    B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# 0               2002.0                5.24                7.19
# 1               2006.0               14.00               14.00
# 2               2007.0                5.00                5.00
# 3               2002.0                4.57               11.79
# 4               1999.0                1.63                2.74
#
#    C3) Funding FY2010  D) Mission-specific or General STEM?   ...    \
# 0                5.70                                     1   ...
# ...

# %%
df=df.drop(['Index Number'],axis=1)

# %%
df.head(5)
# Out:
#    Investment Name  Agency  Subagency  A) Brief Description  \
# 0               31      10         12                    92
# 1               23      10          9                    76
# 2               26      10          9                   240
# 3              174      10         12                   163
# 4               72      10         12                   107
#
#    B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# 0               2002.0                5.24                7.19
# 1               2006.0               14.00               14.00
# 2               2007.0                5.00                5.00
# 3               2002.0                4.57               11.79
# 4               1999.0                1.63                2.74
#
#    C3) Funding FY2010  D) Mission-specific or General STEM?  \
# 0                5.70                                     1
# 1               14.00                                     1
# ...

# %%
df4=df

# %%
df4=df4.drop(['percent_growth','Target'],axis=1)

# %%
df4.head(3)
# Out:
#    Investment Name  Agency  Subagency  A) Brief Description  \
# 0               31      10         12                    92
# 1               23      10          9                    76
# 2               26      10          9                   240
#
#    B) Year Established  C1) Funding FY2008  C2) Funding FY2009  \
# 0               2002.0                5.24                7.19
# 1               2006.0               14.00               14.00
# 2               2007.0                5.00                5.00
#
#    C3) Funding FY2010  D) Mission-specific or General STEM?  \
# 0                5.70                                     1
# 1               14.00                                     1
# 2                4.37                                     1
#
#    E) Agency or Mission-Related Workforce Needs?            ...             \
# 0                                              2            ...
# 1                                              2            ...
# ...

# %%
X=df4
Y=df['Target']

# %% [markdown]
# # Divide data into train & test samples

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.30)

# %%
x_train.shape
# Out:
# (177, 246)

# %%
y_train.shape
# Out:
# (177,)

# %%
x_test.shape
# Out:
# (76, 246)

# %%
y_test.shape
# Out:
# (76,)

# %% [markdown]
# # xgboost Model

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_pred=model.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
predictions=[round(value) for value in y_pred]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 75.00%

# %% [markdown]
# # Improving the Accuracy

# %%
model2=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.6,
       gamma=0.9, learning_rate=0.02, max_delta_step=0, max_depth=5,
       min_child_weight=1, missing=None, n_estimators=900, nthread=1,
       objective='binary:logistic', reg_alpha=0, reg_lambda=1,
       scale_pos_weight=1, seed=0, silent=True, subsample=0.8)

# %%
model2.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.6, gamma=0.9, learning_rate=0.02,
#        max_delta_step=0, max_depth=5, min_child_weight=1, missing=None,
#        n_estimators=900, n_jobs=1, nthread=1, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=0, silent=True, subsample=0.8)

# %%
y_pred2=model2.predict(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
predictions2=[round(value) for value in y_pred2]

# %%
accuracy2 = accuracy_score(y_test, predictions2)
print("Accuracy2 : %.2f%%" % (accuracy2 * 100.0))
# Out:
# Accuracy2 : 80.26%

# %%
model3=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.6,
       gamma=0.9, learning_rate=0.001, max_delta_step=0.03, max_depth=5,
       min_child_weight=1, missing=None, n_estimators=900, nthread=1,
       objective='binary:logistic', reg_alpha=0.005, reg_lambda=1,
       scale_pos_weight=1, seed=0, silent=True, subsample=0.8)

# %%
model3.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.6, gamma=0.9, learning_rate=0.001,
#        max_delta_step=0.03, max_depth=5, min_child_weight=1, missing=None,
#        n_estimators=900, n_jobs=1, nthread=1, objective='binary:logistic',
#        random_state=0, reg_alpha=0.005, reg_lambda=1, scale_pos_weight=1,
#        seed=0, silent=True, subsample=0.8)

# %%
y_pred3=model3.predict(x_test)
predictions3=[round(value) for value in y_pred3]
accuracy3 = accuracy_score(y_test, predictions3)
print("Accuracy3 : %.2f%%" % (accuracy3 * 100.0))
# Out:
# Accuracy3 : 80.26%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# # roc curve

# %%
from sklearn.metrics import roc_curve, auc

# %%
false_pos, true_pos, thresholds = roc_curve(y_test, y_pred2, pos_label=1)
roc_auc = auc(false_pos, true_pos)

# %%
plt.title('ROC')
plt.plot(false_pos, true_pos, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(XGBClassifier(), X, Y, cv=10, scoring='accuracy')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...

# %%
print(scores.mean())
# Out:
# 0.8024045584045585

# %% [markdown]
# # Pytest Framework

# %%
def read_file(path_of_data):
    #if file is not csv raise assertion error of file   not in csv format
    assert path_of_data[-3:]=='csv',"This file is not in  '.csv'  format"
    main_data=pd.read_csv(path_of_data)
    return main_data

# %%
def test_read():
    read_file("D:/Projects/RedCarpetUp/dataset.xls")

# %%
test_read()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-547-3865e14a1da8> in <module>()
# ----> 1 test_read()
#
# <ipython-input-546-306f4b349e5a> in test_read()
#       1 def test_read():
# ----> 2     read_file("D:/Projects/RedCarpetUp/dataset.xls")
#
# <ipython-input-545-8a895ed4d058> in read_file(path_of_data)
#       1 def read_file(path_of_data):
#       2     #if file is not csv raise assertion error of file   not in csv format
# ----> 3     assert path_of_data[-3:]=='csv',"This file is not in  '.csv'  format"
#       4     main_data=pd.read_csv(path_of_data)
#       5     return main_data
#
# AssertionError: This file is not in  '.csv'  format
